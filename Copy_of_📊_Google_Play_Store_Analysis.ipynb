# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Unveiling the Secrets of Top-Rated Apps: A Google Play Store Analysis</h1>

# %% [markdown]
# ![GooglePlayStore.png](attachment:f918a271-7234-4430-88c6-e1c464706cee.png)

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Table Of Content</h1>
#
# * [1. Introduction](#1)
# * [2. Aim of Dataset](#2)
# * [3. About Data](#3)
# * [4. Import Libraries](#4)
# * [5. Import Dataset](#5)
# * [6. Data Exploration and cleaning](#6)
#    * [6.1 Descriptive Statistics](#6.1)
# * [7. Data Visualization](#7)
# * [8. Dealing with Duplicates](#8)
# * [9. Questions Answers](#9)
# * [10. Summary](#10)
# * [11. Conclusion](#11)

# %% [markdown]
# **Auther Name:** Umar Mehmood

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;font-size:200%; letter-spacing:1.0px;"><p style="padding: 5px;color:white;text-align:left;"><b><span style='color:#fc6603'>Social Media Links</span></b></p></div>
#
# <div style="text-align: left;">
#     <table>
#         <tr>
#             <td><a href="https://www.linkedin.com/in/umar-mehmood-147224294/"><img src="https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin" alt="LinkedIn"/></a></td>
#             <td><a href="mailto:umarmehmood885@gmail.com"><img src="https://img.shields.io/badge/Gmail-Profile-red?style=for-the-badge&logo=gmail" alt="Gmail"/></a></td>
#         </tr>
#         <tr>
#             <td><a href="https://github.com/Umar885"><img src="https://img.shields.io/badge/GitHub-Profile-green?style=for-the-badge&logo=github" alt="GitHub"/></a></td>
#             <td><a href="https://twitter.com/UmarMeh12214006"><img src="https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter" alt="Twitter"/></a></td>
#         </tr>
#         <tr>
#             <td><a href="https://www.kaggle.com/umarmehmood"><img src="https://img.shields.io/badge/Kaggle-Profile-orange?style=for-the-badge&logo=kaggle" alt="Kaggle"/></a></td>
#             <td><a href="https://medium.com/@umarmehmood885"><img src="https://img.shields.io/badge/Medium-Profile-black?style=for-the-badge&logo=medium" alt="Medium"/></a></td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# <a id="1"></a>
# <h2 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Introduction</h2>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# *Get ready to explore! We've got a huge dataset with over 2.3 million mobile apps from the Google Play Store. Whether you're into games, productivity, or anything in between, there's something for everyone. Find out about app ratings, installs, and trends – it's all here! Perfect for developers, researchers, and anyone who loves apps. Let's dive in and discover together!*

# %% [markdown]
# <a id="2"></a>
# <h2 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Aim of Datset</h2>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# *The aim of the Google Play Store dataset is to provide comprehensive insights into the vast ecosystem of mobile applications available on the Google Play platform. By compiling data on over 2.3 million apps, this dataset aims to facilitate various analyses and investigations, including:*
# - Understanding app popularity
# - Exploring app categories
# - Investigating pricing strategies
# - Assessing developer engagement
# - Monitoring app updates

# %% [markdown]
# <a id="3"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">About Data</h1>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# * Google PlayStore Android App Data. (2.3 Million+ App Data)
# * Exporatory Data Analysis (EDA) on Google Playstore Dataset
# * The data was collected in the month of June 2021.
# * The Data Set was downloaded from Kaggle, from the following [link](https://www.kaggle.com/datasets/gauthamp10/google-playstore-apps/data)

# %% [markdown]
# > # <h1 style="color: #FF9900;">Kernel Version Used:</h1>
# > * Python 3.11.8

# %% [markdown]
# <a id="4"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Import Libraries</h1>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# # <h1 style="color:Black;"> let me give you a quick rundown of each library:</h1>
# * 1. **pandas 🐼:** Data manipulation and analysis library.
# * 2. **numpy ⚙️:** Numerical computing library for arrays and matrices.
# * 3. **matplotlib 📊:** Plotting library for creating static, interactive, and animated visualizations.
# * 4. **seaborn 🌊**: Statistical data visualization based on matplotlib.
# * 5. **plotly.express 📈:** High-level interface for creating interactive visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# <a id="5"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Import Dataset</h1>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# * Here's how you can import a dataset from a CSV file using Pandas

# %%
df = pd.read_csv('/content/drive/MyDrive/Google-Playstore.csv.zip')

# %% [markdown]
# * This code will load the dataset into a DataFrame named `df`, allowing you to analyze and manipulate the data using Pandas

# %% [markdown]
# <a id="6"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Data Exploration and Cleaning</h1>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# * Displays the first 5 rows of DataFrame.

# %%
df.head(5)
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# ...

# %% [markdown]
# ___
# # **Observation**
# * There are instances where the notebook's output is incomplete.
# * To increase the limit of columns and rows displayed in the output of a notebook, you can use the following commands:
# ___

# %%
# Increase the limit of columns displayed
pd.set_option('display.max_columns', None)
# Increase the limit of rows displayed
#pd.set_option('display.max_rows', None)

# %% [markdown]
# -  Here are the exact column names from the Google Play Store dataset:

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %% [markdown]
# - Let us inquire about the shape of a data set.

# %%
print("The dataset's number of rows: ",df.shape[0])
print("The dataset's number of columns: ",df.shape[1])
# Out:
# The dataset's number of rows:  2312944
# The dataset's number of columns:  24

# %% [markdown]
# - Here's how you can inspect the columns and their data types using the detailed info function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %% [markdown]
# ___
# # **Observations**
# 1. **Dataset Overview:** This section provides a brief summary of the dataset.
# 2. **Rows and Columns:** Indicates the total number of rows (2312944) and columns (24) in the dataset.
# 3. **Column Names:** Lists the names of all columns in the dataset:'App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'
# 4. **Data Types:** Specifies that columns have different data types
# 5. **Missing Values:** Acknowledges the presence of missing values in the dataset
# 6. **Data Quality**: Highlights specific columns ('Size', 'Installs') with object data types that should ideally be numeric
# ___

# %% [markdown]
# <a id="6.1"></a>
# # <h1 style="color: #FF9900;">Descriptive Statistics</h1>

# %%
df.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  2.290061e+06  2.290061e+06      2.312837e+06      2.312944e+06
# mean   2.203152e+00  2.864839e+03      1.834452e+05      3.202017e+05
# std    2.106223e+00  2.121626e+05      1.513144e+07      2.355495e+07
# min    0.000000e+00  0.000000e+00      0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00      5.000000e+01      8.400000e+01
# 50%    2.900000e+00  6.000000e+00      5.000000e+02      6.950000e+02
# 75%    4.300000e+00  4.200000e+01      5.000000e+03      7.354000e+03
# max    5.000000e+00  1.385576e+08      1.000000e+10      1.205763e+10
#
#               Price
# count  2.312944e+06
# mean   1.034992e-01
# std    2.633127e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    4.000000e+02

# %% [markdown]
# ___
# # **Observations**
# - 1. **Numerical Columns:** The numerical value of the five columns.
# - 2. **Rating Range:** Unveil a spectrum of app ratings from 0 to 5 stars.
# - 3. **Install Extremes:** Witness app popularity soar from zero to over 12 billion installs.
# - 4. **Price Bounds:** Explore app costs from free to premium, up to $400.
# ___

# %% [markdown]
# - To check for missing values in the dataset

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer Website    760835
# Privacy Policy       420953
# Released              71053
# Rating                22883
# Rating Count          22883
# Minimum Android        6530
# Size                    196
# Currency                135
# Minimum Installs        107
# Installs                107
# Developer Id             33
# Developer Email          31
# App Name                  5
# Maximum Installs          0
# App Id                    0
# Category                  0
# Price                     0
# Free                      0
# Last Updated              0
# Content Rating            0
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %% [markdown]
# - To calculate the percentage of missing values in the dataset

# %%
df.isnull().sum().sort_values(ascending=False)/len(df)*100
# Out:
# Developer Website    32.894657
# Privacy Policy       18.199879
# Released              3.071972
# Rating                0.989345
# Rating Count          0.989345
# Minimum Android       0.282324
# Size                  0.008474
# Currency              0.005837
# Minimum Installs      0.004626
# Installs              0.004626
# Developer Id          0.001427
# Developer Email       0.001340
# App Name              0.000216
# Maximum Installs      0.000000
# App Id                0.000000
# Category              0.000000
# Price                 0.000000
# Free                  0.000000
# Last Updated          0.000000
# Content Rating        0.000000
# Ad Supported          0.000000
# In App Purchases      0.000000
# Editors Choice        0.000000
# Scraped Time          0.000000
# dtype: float64

# %% [markdown]
# <a id="7"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Data Visualization</h1>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# - To create a plot visualizing the missing values in the dataset.

# %%
# create a missing value plot
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12, 6)
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.title('Missing Value Heatmap')
# Out:
# Text(0.5, 1.0, 'Missing Value Heatmap')

# %% [markdown]
# ___
# # **Observations**
# - 1. **Identify Columns with Highest Missing Values:** Developer website and privacy policy have the highest missing values, making them less useful.
#    - These columns are deemed less useful for exploratory data analysis (EDA).
# - 2. The little null values for the columns can be removed.
#    - Size
#    - Installs
#    - Currency
#    - Minimum installs
#    - Developer ID
#    - Developer Ema
# - 3. When handling missing values for some crucial columns, apply the "fillna" function.
#    - Rating
#    - Rating Count
#    - Released
#    - Minimum Android version
# ___

# %% [markdown]
# # Therefore let's remove the specified columns' null values.

# %%
df.dropna(subset=['Size', 'Currency', 'Installs', 'Minimum Installs', 'App Name','Developer Id', 'Developer Email'  ], inplace=True)

# %%
df.isnull().sum()
# Out:
# App Name                  0
# App Id                    0
# Category                  0
# Rating                22572
# Rating Count          22572
# Installs                  0
# Minimum Installs          0
# Maximum Installs          0
# Free                      0
# Price                     0
# Currency                  0
# Size                      0
# Minimum Android        6530
# Developer Id              0
# Developer Website    760713
# Developer Email           0
# Released              70748
# Last Updated              0
# Content Rating            0
# Privacy Policy       420843
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %% [markdown]
# <a id="8"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Dealing With Duplicates</h1>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# - looking for any App Name duplication

# %%
df['App Name'].duplicated().any()
# Out:
# np.True_

# %%
# apply counts funtions
df['App Name'].value_counts()
# Out:
# App Name
# Tic Tac Toe                                         382
# Calculator                                          261
# Flashlight                                          256
# BMI Calculator                                      201
# Age Calculator                                      190
#                                                    ...
# Beautiful Clock Live Wallpaper                        1
# Medcem Checklist                                      1
# RestockMe                                             1
# Ripplfect                                             1
# Miter Bend Pro | Fabricated, Segment, Cut Bend |      1
# Name: count, Length: 2177592, dtype: int64

# %%
# Select only Tic Tac Toe app name

df[df['App Name'] == 'Tic Tac Toe']
# Out:
#             App Name                             App Id Category  Rating  \
# 3918     Tic Tac Toe           com.dev.atte.tic_tac_toe   Puzzle     0.0
# 13758    Tic Tac Toe                   com.md.tictactoe    Board     0.0
# 25351    Tic Tac Toe        com.sthirumuru.tictactoenew    Board     4.2
# 28142    Tic Tac Toe               com.fsk00x.TicTacToe    Board     0.0
# 30962    Tic Tac Toe         net.snatchdreams.tictactoe   Puzzle     0.0
# ...              ...                                ...      ...     ...
# 2272773  Tic Tac Toe        com.tictactoe.MobileAppsPro    Board     3.8
# 2281376  Tic Tac Toe     com.erjainam.tictactoe.release    Board     0.0
# 2282023  Tic Tac Toe          com.swapworld.tic_tac_toe    Board     4.7
# 2299121  Tic Tac Toe               com.infuse.tictactoe    Board     4.8
# 2310375  Tic Tac Toe  com.justmailtoavi.avinashk.threet   Puzzle     4.7
#
#          Rating Count  Installs  Minimum Installs  Maximum Installs  Free  \
# ...

# %% [markdown]
# ___
# # **Observations**
# - Although all of our apps have the same name, they are differentiated by their unique app identifiers.
# ___

# %% [markdown]
# # <h1 style="color: #FF9900;">Now let's investigate the numbers</h1>

# %%
df['Installs'].unique()
# Out:
# array(['10+', '5,000+', '50+', '100+', '1,000+', '500+', '50,000+',
#        '10,000+', '1+', '500,000+', '100,000+', '5+', '10,000,000+',
#        '1,000,000+', '5,000,000+', '0+', '100,000,000+', '50,000,000+',
#        '1,000,000,000+', '500,000,000+', '5,000,000,000+',
#        '10,000,000,000+'], dtype=object)

# %% [markdown]
# - We must convert it from the object type to the int type.

# %%
# Remove the + symbol
df['Installs'] = df['Installs'].apply(lambda x: x.replace('+', ''))

# %%
# Replace the comas ',' in the installs columns

df['Installs'] = df['Installs'].apply(lambda x: x.replace(',', ''))

# %%
# Convert 'Installs' column to np.int64 type
df['Installs'] = df['Installs'].astype(np.int64)

# %%
df['Installs'].unique()
# Out:
# array([         10,        5000,          50,         100,        1000,
#                500,       50000,       10000,           1,      500000,
#             100000,           5,    10000000,     1000000,     5000000,
#                  0,   100000000,    50000000,  1000000000,   500000000,
#         5000000000, 10000000000])

# %% [markdown]
# ___
# # **Observations**
# - The '+' symbols in our 'Installs' column are removed using a straightforward lambda function, which simplifies our dataset.
# - Comma Removal: Carefully removing commas allows us to weave simplicity into our data fabric.
# - Type Transformation: We carefully shape our 'Installs' column to resemble a np.int64 type.
# ___

# %% [markdown]
# # <h1 style="color: #FF9900;"> Dealing with Size column</h1>

# %%
df['Size'].unique()
# Out:
# array(['10M', '2.9M', '3.7M', ..., '405M', '3.2k', '512M'], dtype=object)

# %%
# This data contain MB, KBs, GBs
# Correct this size and convert this only to MB
df['Size'] = df['Size'].str.replace('M', '000000')
df['Size'] = df['Size'].str.replace('k', '000')
df['Size'] = df['Size'].str.replace('G', '000000000')

# %%
df['Size'] = pd.to_numeric(df['Size'] , errors='coerce')

# %%
# Fill this missing values in Size columns
df['Size'] = df['Size'].fillna(df['Size'].mean())

# %%
df['Size'] = df['Size'].apply(lambda x: x/1000000)

# %%
df['Size'].unique()
# Out:
# array([1.00e+01, 2.90e-06, 3.70e-06, ..., 9.10e+02, 4.05e+02, 5.12e+02])

# %%
df.dtypes['Size']
# Out:
# dtype('float64')

# %% [markdown]
# ___
# # **Observations**
# - Convert sizes to MB by replacing 'M' with '000000' and 'k' with '000', and 'G' with '000000000'.
# - Convert the 'Size' column to numeric values
# - Fill missing values in the 'Size' column with the mean
# - Divide all sizes by 1,000,000 to convert them to MB.
# ___

# %%
df['Minimum Android']
# Out:
# 0            7.1 and up
# 1            5.0 and up
# 2          4.0.3 and up
# 3          4.0.3 and up
# 4            4.1 and up
#                ...
# 2312939      4.1 and up
# 2312940      4.1 and up
# 2312941      5.0 and up
# 2312942      5.0 and up
# 2312943      5.0 and up
# Name: Minimum Android, Length: 2312545, dtype: object

# %%
df['Content Rating']
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3          Everyone
# 4          Everyone
#              ...
# 2312939        Teen
# 2312940    Everyone
# 2312941    Everyone
# 2312942    Everyone
# 2312943    Everyone
# Name: Content Rating, Length: 2312545, dtype: object

# %%
df['Released']
# Out:
# 0          Feb 26, 2020
# 1          May 21, 2020
# 2           Aug 9, 2019
# 3          Sep 10, 2018
# 4          Feb 21, 2020
#                ...
# 2312939             NaN
# 2312940    Jan 17, 2018
# 2312941    Aug 19, 2018
# 2312942     Aug 1, 2016
# 2312943     Aug 9, 2019
# Name: Released, Length: 2312545, dtype: object

# %%
df['Last Updated']
# Out:
# 0          Feb 26, 2020
# 1          May 06, 2021
# 2          Aug 19, 2019
# 3          Oct 13, 2018
# 4          Nov 12, 2018
#                ...
# 2312939    Jun 01, 2021
# 2312940    Feb 02, 2018
# 2312941    Aug 19, 2018
# 2312942    May 05, 2021
# 2312943    Aug 19, 2019
# Name: Last Updated, Length: 2312545, dtype: object

# %% [markdown]
# - Let's clean the columns for content ratings.

# %%
df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           2021785
# Teen                196311
# Mature 17+           60278
# Everyone 10+         33881
# Unrated                154
# Adults only 18+        136
# Name: count, dtype: int64

# %% [markdown]
# ___
# # **Observations**
# 1. The content rating column is divided into several categories.
#  -  Everyone
#  -  Teenager Adult 17 years of age or older
#  -  Everyone 10+
#  -  Not rated
#  -  adults only (18)
#
# For easier comprehension, we are now going to reduce these categories to just three: Everyone, including teenagers and adults
#  -  Mature 17+  ---------> to Adults
#  -  Adults only 18 -----------> to Adults
#  -  Everyone 10+ ------------>  to Teen
#  -  Unrated -------------> Everyone
#   ____

# %%
df['Content Rating'] = df['Content Rating'].replace('Unrated', 'Everyone')
df['Content Rating'] = df['Content Rating'].replace('Adults only 18+', 'Adults')
df['Content Rating'] = df['Content Rating'].replace('Mature 17+', 'Adults')
df['Content Rating'] = df['Content Rating'].replace('Everyone 10+', 'Teen')

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2312545 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           int64
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               float64
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %%
df['Rating Count'].unique()
# Out:
# array([0.0000e+00, 6.4000e+01, 5.0000e+00, ..., 8.7553e+04, 7.5960e+04,
#        7.8351e+04])

# %% [markdown]
# - Let's adjust the rating count to specific ranges so that we can better comprehend the data.

# %%
df['Rating Count'].max()
# Out:
# 138557570.0

# %%
import pandas as pd

# Assuming df is your DataFrame containing the data
# Convert 'Rating Count' column to numeric type
df['Rating Count'] = pd.to_numeric(df['Rating Count'], errors='coerce')

# Define 'Rating Type' column with default value
df['Rating Type'] = 'NoRatingProvided'

# Update 'Rating Count' values based on conditions
df.loc[df['Rating Count']  <= 10000.0, 'Rating Type'] = 'less than 10k'
df.loc[(df['Rating Count'] > 10000) & (df['Rating Count'] <= 500000.0), 'Rating Type'] = '10k - 500k'
df.loc[(df['Rating Count'] > 500000) & (df['Rating Count'] <= 138557570.0), 'Rating Type'] = 'More than 500k'

# Count values in 'Rating Type' column
rating_type_counts = df['Rating Type'].value_counts()

# Show the counts
print(rating_type_counts)
# Out:
# Rating Type
# less than 10k       2252529
# 10k - 500k            35779
# NoRatingProvided      22572
# More than 500k         1665
# Name: count, dtype: int64

# %% [markdown]
# ___
# # **Observations**
# - **less than 10k:** This category represents the apps with a rating count of less than or equal to 10,000.
# - **10k - 500k:** This category includes apps with a rating count ranging from more than 10,000 to 500,000.
# - **More than 500k:** Apps falling into this category have garnered more than 500,000 ratings.
# ____

# %%
df['Rating Type']
# Out:
# 0          less than 10k
# 1          less than 10k
# 2          less than 10k
# 3          less than 10k
# 4          less than 10k
#                ...
# 2312939       10k - 500k
# 2312940    less than 10k
# 2312941    less than 10k
# 2312942    less than 10k
# 2312943    less than 10k
# Name: Rating Type, Length: 2312545, dtype: object

# %% [markdown]
# <a id="9"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Questions Answers</h1>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# - Which Play Store categories have the most Installs, based on the count?
# - According to the count, which 10 categories are there in the Play Store?
# - In what category are the top ten highest ratings?
# - What category has the most popular free and paid apps?
# - What category has the highest number of free and paid app installations?

# %% [markdown]
# - **Q.** According to the count, which 10 categories are there in the Play Store?

# %%
df['Category'].unique()
# Out:
# array(['Adventure', 'Tools', 'Productivity', 'Communication', 'Social',
#        'Libraries & Demo', 'Lifestyle', 'Personalization', 'Racing',
#        'Maps & Navigation', 'Travel & Local', 'Food & Drink',
#        'Books & Reference', 'Medical', 'Puzzle', 'Entertainment',
#        'Arcade', 'Auto & Vehicles', 'Photography', 'Health & Fitness',
#        'Education', 'Shopping', 'Board', 'Music & Audio', 'Sports',
#        'Beauty', 'Business', 'Educational', 'Finance', 'News & Magazines',
#        'Casual', 'Art & Design', 'House & Home', 'Card', 'Events',
#        'Trivia', 'Weather', 'Strategy', 'Word', 'Video Players & Editors',
#        'Action', 'Simulation', 'Music', 'Dating', 'Role Playing',
#        'Casino', 'Comics', 'Parenting'], dtype=object)

# %%
# check this top 10 category use count function
top_category = df.Category.value_counts().reset_index()
top_category.head(10)
# Out:
#             Category   count
# 0          Education  241068
# 1      Music & Audio  154897
# 2              Tools  143971
# 3           Business  143749
# 4      Entertainment  138259
# 5          Lifestyle  118321
# 6  Books & Reference  116716
# 7    Personalization   89207
# 8   Health & Fitness   83497
# 9       Productivity   79681

# %%
# Selecting top 10 categories and their counts
top_10_categories = top_category.head(10)

# Extracting category names and counts
categories = top_10_categories['Category']
counts = top_10_categories['count']

# Define colors for each category
colors = ['skyblue', 'steelblue', 'deepskyblue', 'dodgerblue', 'royalblue',
          'cornflowerblue', 'lightskyblue', 'lightsteelblue', 'mediumblue', 'darkblue']

# Create a bar plot with multiple colors
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, counts)

# Assigning colors to each bar
for i in range(len(bars)):
    bars[i].set_color(colors[i])

plt.title('Top 10 Categories')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(10, 6))
plt.pie(counts, labels=categories, colors=colors, autopct='%1.1f%%')
plt.title('Top 10 Categories')
plt.show()

# %%
# create a bar plot show the all category

plt.figure(figsize=(10, 6))
plt.bar(top_category['Category'], top_category['count'], color=colors)
plt.title('Top 10 Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Ans:** Explore the top ten categories on the Play Store: With 241,068 downloads, education is the most popular category. Other categories include tools, music, books, business, entertainment, personalization, health, and productivity. Discover a wide range of products that suit every interest and lifestyle, from productivity tools to learning resources.

# %% [markdown]
# - **Q.** Which Play Store categories have the most Installs, based on the count?

# %%
# Use the groupby function to check this category based on install.
Category_install = df.groupby('Category')['Installs'].sum().reset_index()
Category_install.head(10)
# Out:
#             Category     Installs
# 0             Action  17399855328
# 1          Adventure   5390108856
# 2             Arcade  14501230845
# 3       Art & Design   1116398902
# 4    Auto & Vehicles   1594745418
# 5             Beauty    404328787
# 6              Board   3290826164
# 7  Books & Reference   4819175179
# 8           Business   5236661902
# 9               Card   1989318718

# %%
Category_install = df.groupby('Category')['Installs'].sum().reset_index()
Category_install.head(10)
# Out:
#             Category     Installs
# 0             Action  17399855328
# 1          Adventure   5390108856
# 2             Arcade  14501230845
# 3       Art & Design   1116398902
# 4    Auto & Vehicles   1594745418
# 5             Beauty    404328787
# 6              Board   3290826164
# 7  Books & Reference   4819175179
# 8           Business   5236661902
# 9               Card   1989318718

# %%
top_category_install = pd.merge( top_category, Category_install, on='Category')
top_category_install.head(10)
# Out:
#             Category   count     Installs
# 0          Education  241068   5983815847
# 1      Music & Audio  154897  14239401798
# 2              Tools  143971  71440271217
# 3           Business  143749   5236661902
# 4      Entertainment  138259  17108396833
# 5          Lifestyle  118321   5997921096
# 6  Books & Reference  116716   4819175179
# 7    Personalization   89207   9252971243
# 8   Health & Fitness   83497   4586600201
# 9       Productivity   79681  28313922253

# %%
# use the sort value function
top_category_install = top_category_install.sort_values(by='Installs', ascending=False).head(10)

# %%
import matplotlib.pyplot as plt

# Define colors for each bar
colors = ['skyblue', 'steelblue', 'deepskyblue', 'dodgerblue', 'royalblue',
          'cornflowerblue', 'lightskyblue', 'lightsteelblue', 'mediumblue', 'darkblue']

plt.figure(figsize=(10, 6))
plt.bar(top_category_install['Category'], top_category_install['Installs'], color=colors)
plt.title('Top 10 Install Categories')
plt.xlabel('Category')
plt.ylabel('Installs')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Ans.** The most popular app categories in the Play Store can be found by sorting the category values according to the number of installations. In order to help developers create apps that have an effect and meet a variety of requirements and interests, these categories—which are led by Tools, Communication, Productivity, Entertainment, and Personalization—highlight user preferences.

# %% [markdown]
# ___
# # **Observations**
# The two plots show us that the majority of the apps in the Google Play Store fall into the categories of business, entertainment, and educational tools. The categories vary depending on how the installation goes. For example, the most installed apps fall under the categories of tools, productivity, entertainment, and audio and music.
# ___

# %% [markdown]
# - **Q.** In what category are the top ten highest ratings?

# %%
top_category_rating = df.groupby('Category')['Rating'].mean().reset_index()
top_category_rating = top_category_rating.sort_values(by='Rating', ascending=False).head(10)
top_category_rating.head(10)
# Out:
#                    Category    Rating
# 36             Role Playing  3.384498
# 10                   Casino  3.279682
# 38               Simulation  3.210887
# 46                  Weather  3.120171
# 9                      Card  3.085171
# 35                   Racing  2.960385
# 45  Video Players & Editors  2.903842
# 47                     Word  2.902076
# 41                 Strategy  2.878900
# 12                   Comics  2.864906

# %%
# Check this top 10 highest rating category
plt.figure(figsize=(10, 6))
plt.bar(top_category_rating['Category'], top_category_rating['Rating'], color=colors)

plt.xlabel('Category')

plt.ylabel('Rating')

plt.title('Top 10 Category with highest rating')

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.xticks(rotation=90)
plt.xlabel("High Rated Category")
plt.ylabel("Number of Applications")
plt.title("All Category Rating")
sns.barplot(x=df.Category, y=df.Rating)
# Out:
# <Axes: title={'center': 'All Category Rating'}, xlabel='High Rated Category', ylabel='Number of Applications'>

# %% [markdown]
# **Ans.** The top ten highest-rated categories are Role Playing, Casino, Simulation, Weather, Card, Racing, Video Players & Editors, Word, Strategy, and Comics. These categories have received the highest average ratings, indicating user satisfaction and appreciation within the Play Store

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %%
# Based on the maximum install and content rating, create a scatter plot.
plt.figure(figsize=(14, 7))
plt.xticks(rotation=90)
plt.xlabel("Content Rating")
plt.ylabel("Maximum Installs")
plt.title("Content Rating vs Maximum Installs")
sns.scatterplot(data=df, x="Maximum Installs", y="Rating Count", hue="Content Rating")
# Out:
# <Axes: title={'center': 'Content Rating vs Maximum Installs'}, xlabel='Content Rating', ylabel='Maximum Installs'>
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# - **Q.** What category has the most popular free and paid apps?

# %%
# Look at this list of the best-paid and free apps by category and function

df.groupby('Category')['Price'].value_counts().reset_index(name='Count').sort_values(by='Count', ascending=False).head(10)
# Out:
#                Category  Price   Count
# 806           Education    0.0  234521
# 2038      Music & Audio    0.0  153373
# 481            Business    0.0  143079
# 2936              Tools    0.0  139894
# 1192      Entertainment    0.0  136878
# 1585          Lifestyle    0.0  116979
# 292   Books & Reference    0.0  113119
# 2189    Personalization    0.0   83440
# 1422   Health & Fitness    0.0   82085
# 2348       Productivity    0.0   77950

# %%
# Make a bar plan and substitute True with False. Both free and Paid

df['Free'] = df['Price'] == 0
df['Free'] = df['Free'].replace({False: 'Paid', True: 'Free'})

# %%
# Display the top-ranked free and paid app categories using a bar plot
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Highest Free and paid app category')
sns.countplot(x='Category', data=df, hue='Free')
# Out:
# <Axes: title={'center': 'Highest Free and paid app category'}, xlabel='Category', ylabel='Count'>

# %% [markdown]
#  **Ans.** The most popular free and paid apps fall under the categories of education, tools, and entertainment.

# %% [markdown]
# - **Q.** What category has the highest number of free and paid app installations?

# %%
# Make a bar chart. display the top 10 categories for both free and premium apps based on the maximum number of installs.
top_category = df.groupby('Category')['Maximum Installs'].max().reset_index().sort_values(by='Maximum Installs', ascending=False).head(10)

plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Highest Free and paid app category based on the Maximum installs')
sns.barplot(x='Category', y='Maximum Installs', data=df, hue='Free')
# Out:
# <Axes: title={'center': 'Highest Free and paid app category based on the Maximum installs'}, xlabel='Category', ylabel='Count'>

# %% [markdown]
# **Ans.** Video Players & Editors is the most installed app in the free app category, according to an analysis of data from the Google Play Store dataset.

# %%
# Create a pie plot show the persentage of insatll free and paid apps category
plt.figure(figsize=(6,6))
plt.pie(df['Free'].value_counts(), labels=['Free', 'Paid'], autopct='%1.1f%%')
plt.title('Persentage of insatll free and paid apps category')
plt.show()

# %% [markdown]
# ___
# # **Observations**
# With 98.1% of installs for free apps and only 1.9% for paid apps, it's evident users prefer free options. The developer should prioritize the free app category to capitalize on this trend. 📊
# ___

# %% [markdown]
# <a id="10"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Summary</h1>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# The Google Play Store dataset contains valuable information about various apps available on the platform. It includes attributes such as App Name, Category, Rating, Reviews, Installs, Price, and more. After cleaning and preprocessing the data, we conducted exploratory data analysis to gain insights into app trends and user preferences.

# %% [markdown]
# <a id="11"></a>
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Conclusion</h1>

# %% [markdown]
# [Table of Content](#13)

# %% [markdown]
# Developers, marketers, and users can all gain insights from the Google Play Store dataset. App developers can add features, improve apps, and change prices. Marketers are better at focusing on specific audiences. Users search for and review apps to download. It provides a comprehensive overview of the dynamic app ecosystem overall.

# %% [markdown]
# <h1 style="background-color:#334460;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">The End</h1>
